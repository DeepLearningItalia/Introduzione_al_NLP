# %% [markdown]
# In this notebook, we will use functions from the [Scikit-learn](https://scikit-learn.org/stable/index.html) library to create a word-document matrix and compute the Singular Value Decomposition to implement Latent Semantic Analysis.
#
# The sentences, already tokenized, are taken from the [Parallel Meaning Bank](https://pmb.let.rug.nl/) version 1.0.0.

# %%
# !wget https://pmb.let.rug.nl/releases/pmb-1.0.0.zip
# !unzip pmb-1.0.0.zip

from glob import glob
corpus = []
for filename in glob("pmb-1.0.0/data/p*/d*/en.tok.off"):
    with open(filename) as f:
        lines = f.readlines()
        tokens = []
        for line in lines:
            tokens.append(" ".join(line.strip().split(" ")[3:]))
        corpus.append(" ".join(tokens))
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: pmb-1.0.0/data/p09/d1939/en.met
#  extracting: pmb-1.0.0/data/p09/d1939/en.raw
#   inflating: pmb-1.0.0/data/p09/d1939/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d1939/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d1939/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d1939/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d1939/en.drs.box
#    creating: pmb-1.0.0/data/p09/d2378/
#   inflating: pmb-1.0.0/data/p09/d2378/en.met
#  extracting: pmb-1.0.0/data/p09/d2378/en.raw
#   inflating: pmb-1.0.0/data/p09/d2378/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d2378/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d2378/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d2378/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d2378/en.drs.box
#    creating: pmb-1.0.0/data/p09/d2883/
#   inflating: pmb-1.0.0/data/p09/d2883/en.met
#  extracting: pmb-1.0.0/data/p09/d2883/en.raw
#   inflating: pmb-1.0.0/data/p09/d2883/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d2883/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d2883/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d2883/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d2883/en.drs.box
#    creating: pmb-1.0.0/data/p09/d1559/
#   inflating: pmb-1.0.0/data/p09/d1559/en.met
#  extracting: pmb-1.0.0/data/p09/d1559/en.raw
#   inflating: pmb-1.0.0/data/p09/d1559/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d1559/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d1559/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d1559/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d1559/en.drs.box
#    creating: pmb-1.0.0/data/p09/d2497/
#   inflating: pmb-1.0.0/data/p09/d2497/en.met
#  extracting: pmb-1.0.0/data/p09/d2497/en.raw
#   inflating: pmb-1.0.0/data/p09/d2497/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d2497/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d2497/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d2497/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d2497/en.drs.box
#    creating: pmb-1.0.0/data/p09/d2862/
#   inflating: pmb-1.0.0/data/p09/d2862/en.met
#  extracting: pmb-1.0.0/data/p09/d2862/en.raw
#   inflating: pmb-1.0.0/data/p09/d2862/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d2862/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d2862/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d2862/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d2862/en.drs.box
#    creating: pmb-1.0.0/data/p09/d1702/
#   inflating: pmb-1.0.0/data/p09/d1702/en.met
#  extracting: pmb-1.0.0/data/p09/d1702/en.raw
#   inflating: pmb-1.0.0/data/p09/d1702/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d1702/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d1702/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d1702/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d1702/en.drs.box
#    creating: pmb-1.0.0/data/p09/d3009/
#   inflating: pmb-1.0.0/data/p09/d3009/en.met
#  extracting: pmb-1.0.0/data/p09/d3009/en.raw
#   inflating: pmb-1.0.0/data/p09/d3009/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d3009/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d3009/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d3009/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d3009/en.drs.box
#    creating: pmb-1.0.0/data/p09/d1669/
#   inflating: pmb-1.0.0/data/p09/d1669/en.met
#  extracting: pmb-1.0.0/data/p09/d1669/en.raw
#   inflating: pmb-1.0.0/data/p09/d1669/en.drs.tpl
#   inflating: pmb-1.0.0/data/p09/d1669/en.drs.xml
#   inflating: pmb-1.0.0/data/p09/d1669/en.tok.off
#   inflating: pmb-1.0.0/data/p09/d1669/en.tok.iob
#   inflating: pmb-1.0.0/data/p09/d1669/en.drs.box
#    creating: pmb-1.0.0/data/p59/
#    creating: pmb-1.0.0/data/p59/d1760/
#   inflating: pmb-1.0.0/data/p59/d1760/en.met
#  extracting: pmb-1.0.0/data/p59/d1760/en.raw
#   inflating: pmb-1.0.0/data/p59/d1760/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d1760/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d1760/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d1760/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d1760/en.drs.box
#    creating: pmb-1.0.0/data/p59/d3246/
#   inflating: pmb-1.0.0/data/p59/d3246/en.met
#  extracting: pmb-1.0.0/data/p59/d3246/en.raw
#   inflating: pmb-1.0.0/data/p59/d3246/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d3246/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d3246/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d3246/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3246/en.drs.box
#    creating: pmb-1.0.0/data/p59/d2379/
#   inflating: pmb-1.0.0/data/p59/d2379/en.met
#  extracting: pmb-1.0.0/data/p59/d2379/en.raw
#   inflating: pmb-1.0.0/data/p59/d2379/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d2379/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d2379/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d2379/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d2379/en.drs.box
#    creating: pmb-1.0.0/data/p59/d1714/
#   inflating: pmb-1.0.0/data/p59/d1714/en.met
#  extracting: pmb-1.0.0/data/p59/d1714/en.raw
#   inflating: pmb-1.0.0/data/p59/d1714/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d1714/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d1714/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d1714/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d1714/en.drs.box
#    creating: pmb-1.0.0/data/p59/d3120/
#   inflating: pmb-1.0.0/data/p59/d3120/en.met
#  extracting: pmb-1.0.0/data/p59/d3120/en.raw
#   inflating: pmb-1.0.0/data/p59/d3120/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d3120/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d3120/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d3120/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3120/en.drs.box
#    creating: pmb-1.0.0/data/p59/d3126/
#   inflating: pmb-1.0.0/data/p59/d3126/en.met
#  extracting: pmb-1.0.0/data/p59/d3126/en.raw
#   inflating: pmb-1.0.0/data/p59/d3126/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d3126/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d3126/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d3126/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3126/en.drs.box
#    creating: pmb-1.0.0/data/p59/d3169/
#   inflating: pmb-1.0.0/data/p59/d3169/en.met
#   inflating: pmb-1.0.0/data/p59/d3169/nl.drs.xml
#  extracting: pmb-1.0.0/data/p59/d3169/en.raw
#   inflating: pmb-1.0.0/data/p59/d3169/nl.drs.box
#   inflating: pmb-1.0.0/data/p59/d3169/en.drs.tpl
#  extracting: pmb-1.0.0/data/p59/d3169/nl.raw
#   inflating: pmb-1.0.0/data/p59/d3169/nl.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3169/nl.tok.off
#   inflating: pmb-1.0.0/data/p59/d3169/nl.met
#   inflating: pmb-1.0.0/data/p59/d3169/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d3169/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d3169/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d3169/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3169/en.drs.box
#    creating: pmb-1.0.0/data/p59/d2698/
#   inflating: pmb-1.0.0/data/p59/d2698/en.met
#  extracting: pmb-1.0.0/data/p59/d2698/en.raw
#   inflating: pmb-1.0.0/data/p59/d2698/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d2698/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d2698/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d2698/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d2698/en.drs.box
#    creating: pmb-1.0.0/data/p59/d1811/
#   inflating: pmb-1.0.0/data/p59/d1811/en.met
#  extracting: pmb-1.0.0/data/p59/d1811/en.raw
#   inflating: pmb-1.0.0/data/p59/d1811/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d1811/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d1811/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d1811/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d1811/en.drs.box
#    creating: pmb-1.0.0/data/p59/d0888/
#   inflating: pmb-1.0.0/data/p59/d0888/en.met
#   inflating: pmb-1.0.0/data/p59/d0888/nl.drs.xml
#   inflating: pmb-1.0.0/data/p59/d0888/it.drs.xml
#   inflating: pmb-1.0.0/data/p59/d0888/de.drs.xml
#   inflating: pmb-1.0.0/data/p59/d0888/it.tok.off
#  extracting: pmb-1.0.0/data/p59/d0888/en.raw
#   inflating: pmb-1.0.0/data/p59/d0888/it.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d0888/nl.drs.box
#   inflating: pmb-1.0.0/data/p59/d0888/it.drs.box
#   inflating: pmb-1.0.0/data/p59/d0888/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d0888/it.tok.iob
#   inflating: pmb-1.0.0/data/p59/d0888/de.tok.off
#  extracting: pmb-1.0.0/data/p59/d0888/nl.raw
#   inflating: pmb-1.0.0/data/p59/d0888/nl.tok.iob
#   inflating: pmb-1.0.0/data/p59/d0888/nl.tok.off
#  extracting: pmb-1.0.0/data/p59/d0888/it.raw
#   inflating: pmb-1.0.0/data/p59/d0888/de.met
#   inflating: pmb-1.0.0/data/p59/d0888/nl.met
#   inflating: pmb-1.0.0/data/p59/d0888/de.tok.iob
#   inflating: pmb-1.0.0/data/p59/d0888/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d0888/de.drs.box
#  extracting: pmb-1.0.0/data/p59/d0888/de.raw
#   inflating: pmb-1.0.0/data/p59/d0888/de.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d0888/it.met
#   inflating: pmb-1.0.0/data/p59/d0888/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d0888/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d0888/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d0888/en.drs.box
#    creating: pmb-1.0.0/data/p59/d2986/
#   inflating: pmb-1.0.0/data/p59/d2986/en.met
#  extracting: pmb-1.0.0/data/p59/d2986/en.raw
#   inflating: pmb-1.0.0/data/p59/d2986/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d2986/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d2986/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d2986/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d2986/en.drs.box
#    creating: pmb-1.0.0/data/p59/d2521/
#   inflating: pmb-1.0.0/data/p59/d2521/en.met
#  extracting: pmb-1.0.0/data/p59/d2521/en.raw
#   inflating: pmb-1.0.0/data/p59/d2521/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d2521/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d2521/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d2521/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d2521/en.drs.box
#    creating: pmb-1.0.0/data/p59/d2673/
#   inflating: pmb-1.0.0/data/p59/d2673/en.met
#  extracting: pmb-1.0.0/data/p59/d2673/en.raw
#   inflating: pmb-1.0.0/data/p59/d2673/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d2673/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d2673/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d2673/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d2673/en.drs.box
#    creating: pmb-1.0.0/data/p59/d3323/
#   inflating: pmb-1.0.0/data/p59/d3323/en.met
#   inflating: pmb-1.0.0/data/p59/d3323/en.raw
#   inflating: pmb-1.0.0/data/p59/d3323/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d3323/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d3323/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d3323/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3323/en.drs.box
#    creating: pmb-1.0.0/data/p59/d2303/
#   inflating: pmb-1.0.0/data/p59/d2303/en.met
#  extracting: pmb-1.0.0/data/p59/d2303/en.raw
#   inflating: pmb-1.0.0/data/p59/d2303/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d2303/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d2303/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d2303/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d2303/en.drs.box
#    creating: pmb-1.0.0/data/p59/d2257/
#   inflating: pmb-1.0.0/data/p59/d2257/en.met
#  extracting: pmb-1.0.0/data/p59/d2257/en.raw
#   inflating: pmb-1.0.0/data/p59/d2257/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d2257/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d2257/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d2257/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d2257/en.drs.box
#    creating: pmb-1.0.0/data/p59/d3416/
#   inflating: pmb-1.0.0/data/p59/d3416/en.met
#  extracting: pmb-1.0.0/data/p59/d3416/en.raw
#   inflating: pmb-1.0.0/data/p59/d3416/en.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d3416/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d3416/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d3416/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3416/en.drs.box
#    creating: pmb-1.0.0/data/p59/d3163/
#   inflating: pmb-1.0.0/data/p59/d3163/en.met
#   inflating: pmb-1.0.0/data/p59/d3163/nl.drs.xml
#  extracting: pmb-1.0.0/data/p59/d3163/en.raw
#   inflating: pmb-1.0.0/data/p59/d3163/nl.drs.box
#   inflating: pmb-1.0.0/data/p59/d3163/en.drs.tpl
#  extracting: pmb-1.0.0/data/p59/d3163/nl.raw
#   inflating: pmb-1.0.0/data/p59/d3163/nl.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3163/nl.tok.off
#   inflating: pmb-1.0.0/data/p59/d3163/nl.met
#   inflating: pmb-1.0.0/data/p59/d3163/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p59/d3163/en.drs.xml
#   inflating: pmb-1.0.0/data/p59/d3163/en.tok.off
#   inflating: pmb-1.0.0/data/p59/d3163/en.tok.iob
#   inflating: pmb-1.0.0/data/p59/d3163/en.drs.box
#    creating: pmb-1.0.0/data/p25/
#    creating: pmb-1.0.0/data/p25/d3281/
#   inflating: pmb-1.0.0/data/p25/d3281/en.met
#   inflating: pmb-1.0.0/data/p25/d3281/nl.drs.xml
#   inflating: pmb-1.0.0/data/p25/d3281/it.drs.xml
#   inflating: pmb-1.0.0/data/p25/d3281/it.tok.off
#  extracting: pmb-1.0.0/data/p25/d3281/en.raw
#   inflating: pmb-1.0.0/data/p25/d3281/it.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3281/nl.drs.box
#   inflating: pmb-1.0.0/data/p25/d3281/it.drs.box
#   inflating: pmb-1.0.0/data/p25/d3281/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3281/it.tok.iob
#  extracting: pmb-1.0.0/data/p25/d3281/nl.raw
#   inflating: pmb-1.0.0/data/p25/d3281/nl.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3281/nl.tok.off
#  extracting: pmb-1.0.0/data/p25/d3281/it.raw
#   inflating: pmb-1.0.0/data/p25/d3281/nl.met
#   inflating: pmb-1.0.0/data/p25/d3281/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3281/it.met
#   inflating: pmb-1.0.0/data/p25/d3281/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d3281/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d3281/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3281/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2773/
#   inflating: pmb-1.0.0/data/p25/d2773/en.met
#   inflating: pmb-1.0.0/data/p25/d2773/de.drs.xml
#  extracting: pmb-1.0.0/data/p25/d2773/en.raw
#   inflating: pmb-1.0.0/data/p25/d2773/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2773/de.tok.off
#   inflating: pmb-1.0.0/data/p25/d2773/de.met
#   inflating: pmb-1.0.0/data/p25/d2773/de.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2773/de.drs.box
#  extracting: pmb-1.0.0/data/p25/d2773/de.raw
#   inflating: pmb-1.0.0/data/p25/d2773/de.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2773/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2773/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2773/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2773/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2538/
#   inflating: pmb-1.0.0/data/p25/d2538/en.met
#  extracting: pmb-1.0.0/data/p25/d2538/en.raw
#   inflating: pmb-1.0.0/data/p25/d2538/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2538/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2538/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2538/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2538/en.drs.box
#    creating: pmb-1.0.0/data/p25/d0953/
#   inflating: pmb-1.0.0/data/p25/d0953/en.met
#  extracting: pmb-1.0.0/data/p25/d0953/en.raw
#   inflating: pmb-1.0.0/data/p25/d0953/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0953/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0953/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d0953/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0953/en.drs.box
#    creating: pmb-1.0.0/data/p25/d3162/
#   inflating: pmb-1.0.0/data/p25/d3162/en.met
#   inflating: pmb-1.0.0/data/p25/d3162/de.drs.xml
#  extracting: pmb-1.0.0/data/p25/d3162/en.raw
#   inflating: pmb-1.0.0/data/p25/d3162/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3162/de.tok.off
#   inflating: pmb-1.0.0/data/p25/d3162/de.met
#   inflating: pmb-1.0.0/data/p25/d3162/de.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3162/de.drs.box
#  extracting: pmb-1.0.0/data/p25/d3162/de.raw
#   inflating: pmb-1.0.0/data/p25/d3162/de.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3162/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d3162/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d3162/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3162/en.drs.box
#    creating: pmb-1.0.0/data/p25/d1986/
#   inflating: pmb-1.0.0/data/p25/d1986/en.met
#  extracting: pmb-1.0.0/data/p25/d1986/en.raw
#   inflating: pmb-1.0.0/data/p25/d1986/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d1986/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d1986/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d1986/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d1986/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2468/
#   inflating: pmb-1.0.0/data/p25/d2468/en.met
#   inflating: pmb-1.0.0/data/p25/d2468/de.drs.xml
#  extracting: pmb-1.0.0/data/p25/d2468/en.raw
#   inflating: pmb-1.0.0/data/p25/d2468/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2468/de.tok.off
#   inflating: pmb-1.0.0/data/p25/d2468/de.met
#   inflating: pmb-1.0.0/data/p25/d2468/de.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2468/de.drs.box
#  extracting: pmb-1.0.0/data/p25/d2468/de.raw
#   inflating: pmb-1.0.0/data/p25/d2468/de.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2468/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2468/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2468/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2468/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2627/
#   inflating: pmb-1.0.0/data/p25/d2627/en.met
#  extracting: pmb-1.0.0/data/p25/d2627/en.raw
#   inflating: pmb-1.0.0/data/p25/d2627/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2627/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2627/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2627/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2627/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2302/
#   inflating: pmb-1.0.0/data/p25/d2302/en.met
#  extracting: pmb-1.0.0/data/p25/d2302/en.raw
#   inflating: pmb-1.0.0/data/p25/d2302/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2302/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2302/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2302/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2302/en.drs.box
#    creating: pmb-1.0.0/data/p25/d0713/
#   inflating: pmb-1.0.0/data/p25/d0713/en.met
#   inflating: pmb-1.0.0/data/p25/d0713/nl.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0713/it.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0713/de.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0713/it.tok.off
#  extracting: pmb-1.0.0/data/p25/d0713/en.raw
#   inflating: pmb-1.0.0/data/p25/d0713/it.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0713/nl.drs.box
#   inflating: pmb-1.0.0/data/p25/d0713/it.drs.box
#   inflating: pmb-1.0.0/data/p25/d0713/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0713/it.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0713/de.tok.off
#   inflating: pmb-1.0.0/data/p25/d0713/nl.raw
#   inflating: pmb-1.0.0/data/p25/d0713/nl.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0713/nl.tok.off
#  extracting: pmb-1.0.0/data/p25/d0713/it.raw
#   inflating: pmb-1.0.0/data/p25/d0713/de.met
#   inflating: pmb-1.0.0/data/p25/d0713/nl.met
#   inflating: pmb-1.0.0/data/p25/d0713/de.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0713/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0713/de.drs.box
#  extracting: pmb-1.0.0/data/p25/d0713/de.raw
#   inflating: pmb-1.0.0/data/p25/d0713/de.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0713/it.met
#   inflating: pmb-1.0.0/data/p25/d0713/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0713/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d0713/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0713/en.drs.box
#    creating: pmb-1.0.0/data/p25/d3409/
#   inflating: pmb-1.0.0/data/p25/d3409/en.met
#  extracting: pmb-1.0.0/data/p25/d3409/en.raw
#   inflating: pmb-1.0.0/data/p25/d3409/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3409/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d3409/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d3409/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3409/en.drs.box
#    creating: pmb-1.0.0/data/p25/d1895/
#   inflating: pmb-1.0.0/data/p25/d1895/en.met
#  extracting: pmb-1.0.0/data/p25/d1895/en.raw
#   inflating: pmb-1.0.0/data/p25/d1895/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d1895/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d1895/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d1895/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d1895/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2748/
#   inflating: pmb-1.0.0/data/p25/d2748/en.met
#   inflating: pmb-1.0.0/data/p25/d2748/nl.drs.xml
#  extracting: pmb-1.0.0/data/p25/d2748/en.raw
#   inflating: pmb-1.0.0/data/p25/d2748/nl.drs.box
#   inflating: pmb-1.0.0/data/p25/d2748/en.drs.tpl
#  extracting: pmb-1.0.0/data/p25/d2748/nl.raw
#   inflating: pmb-1.0.0/data/p25/d2748/nl.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2748/nl.tok.off
#   inflating: pmb-1.0.0/data/p25/d2748/nl.met
#   inflating: pmb-1.0.0/data/p25/d2748/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2748/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2748/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2748/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2748/en.drs.box
#    creating: pmb-1.0.0/data/p25/d3091/
#   inflating: pmb-1.0.0/data/p25/d3091/en.met
#  extracting: pmb-1.0.0/data/p25/d3091/en.raw
#   inflating: pmb-1.0.0/data/p25/d3091/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3091/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d3091/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d3091/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3091/en.drs.box
#    creating: pmb-1.0.0/data/p25/d0760/
#   inflating: pmb-1.0.0/data/p25/d0760/en.met
#   inflating: pmb-1.0.0/data/p25/d0760/nl.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0760/it.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0760/de.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0760/it.tok.off
#  extracting: pmb-1.0.0/data/p25/d0760/en.raw
#   inflating: pmb-1.0.0/data/p25/d0760/it.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0760/nl.drs.box
#   inflating: pmb-1.0.0/data/p25/d0760/it.drs.box
#   inflating: pmb-1.0.0/data/p25/d0760/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0760/it.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0760/de.tok.off
#  extracting: pmb-1.0.0/data/p25/d0760/nl.raw
#   inflating: pmb-1.0.0/data/p25/d0760/nl.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0760/nl.tok.off
#  extracting: pmb-1.0.0/data/p25/d0760/it.raw
#   inflating: pmb-1.0.0/data/p25/d0760/de.met
#   inflating: pmb-1.0.0/data/p25/d0760/nl.met
#   inflating: pmb-1.0.0/data/p25/d0760/de.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0760/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0760/de.drs.box
#  extracting: pmb-1.0.0/data/p25/d0760/de.raw
#   inflating: pmb-1.0.0/data/p25/d0760/de.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d0760/it.met
#   inflating: pmb-1.0.0/data/p25/d0760/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d0760/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d0760/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d0760/en.drs.box
#    creating: pmb-1.0.0/data/p25/d1960/
#   inflating: pmb-1.0.0/data/p25/d1960/en.met
#  extracting: pmb-1.0.0/data/p25/d1960/en.raw
#   inflating: pmb-1.0.0/data/p25/d1960/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d1960/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d1960/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d1960/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d1960/en.drs.box
#    creating: pmb-1.0.0/data/p25/d1835/
#   inflating: pmb-1.0.0/data/p25/d1835/en.met
#   inflating: pmb-1.0.0/data/p25/d1835/it.drs.xml
#   inflating: pmb-1.0.0/data/p25/d1835/it.tok.off
#  extracting: pmb-1.0.0/data/p25/d1835/en.raw
#   inflating: pmb-1.0.0/data/p25/d1835/it.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d1835/it.drs.box
#   inflating: pmb-1.0.0/data/p25/d1835/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d1835/it.tok.iob
#  extracting: pmb-1.0.0/data/p25/d1835/it.raw
#   inflating: pmb-1.0.0/data/p25/d1835/it.met
#   inflating: pmb-1.0.0/data/p25/d1835/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d1835/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d1835/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d1835/en.drs.box
#    creating: pmb-1.0.0/data/p25/d1763/
#   inflating: pmb-1.0.0/data/p25/d1763/en.met
#  extracting: pmb-1.0.0/data/p25/d1763/en.raw
#   inflating: pmb-1.0.0/data/p25/d1763/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d1763/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d1763/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d1763/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d1763/en.drs.box
#    creating: pmb-1.0.0/data/p25/d3207/
#   inflating: pmb-1.0.0/data/p25/d3207/en.met
#   inflating: pmb-1.0.0/data/p25/d3207/de.drs.xml
#  extracting: pmb-1.0.0/data/p25/d3207/en.raw
#   inflating: pmb-1.0.0/data/p25/d3207/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3207/de.tok.off
#   inflating: pmb-1.0.0/data/p25/d3207/de.met
#   inflating: pmb-1.0.0/data/p25/d3207/de.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3207/de.drs.box
#  extracting: pmb-1.0.0/data/p25/d3207/de.raw
#   inflating: pmb-1.0.0/data/p25/d3207/de.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d3207/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d3207/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d3207/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d3207/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2372/
#   inflating: pmb-1.0.0/data/p25/d2372/en.met
#   inflating: pmb-1.0.0/data/p25/d2372/nl.drs.xml
#  extracting: pmb-1.0.0/data/p25/d2372/en.raw
#   inflating: pmb-1.0.0/data/p25/d2372/nl.drs.box
#   inflating: pmb-1.0.0/data/p25/d2372/en.drs.tpl
#  extracting: pmb-1.0.0/data/p25/d2372/nl.raw
#   inflating: pmb-1.0.0/data/p25/d2372/nl.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2372/nl.tok.off
#   inflating: pmb-1.0.0/data/p25/d2372/nl.met
#   inflating: pmb-1.0.0/data/p25/d2372/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2372/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2372/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2372/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2372/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2881/
#   inflating: pmb-1.0.0/data/p25/d2881/en.met
#  extracting: pmb-1.0.0/data/p25/d2881/en.raw
#   inflating: pmb-1.0.0/data/p25/d2881/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2881/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2881/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2881/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2881/en.drs.box
#    creating: pmb-1.0.0/data/p25/d2843/
#   inflating: pmb-1.0.0/data/p25/d2843/en.met
#   inflating: pmb-1.0.0/data/p25/d2843/it.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2843/de.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2843/it.tok.off
#  extracting: pmb-1.0.0/data/p25/d2843/en.raw
#   inflating: pmb-1.0.0/data/p25/d2843/it.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2843/it.drs.box
#   inflating: pmb-1.0.0/data/p25/d2843/en.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2843/it.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2843/de.tok.off
#  extracting: pmb-1.0.0/data/p25/d2843/it.raw
#   inflating: pmb-1.0.0/data/p25/d2843/de.met
#   inflating: pmb-1.0.0/data/p25/d2843/de.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2843/de.drs.box
#  extracting: pmb-1.0.0/data/p25/d2843/de.raw
#   inflating: pmb-1.0.0/data/p25/d2843/de.drs.tpl
#   inflating: pmb-1.0.0/data/p25/d2843/it.met
#   inflating: pmb-1.0.0/data/p25/d2843/en.drs.xml
#   inflating: pmb-1.0.0/data/p25/d2843/en.tok.off
#   inflating: pmb-1.0.0/data/p25/d2843/en.tok.iob
#   inflating: pmb-1.0.0/data/p25/d2843/en.drs.box
#    creating: pmb-1.0.0/data/p75/
#    creating: pmb-1.0.0/data/p75/d2819/
#   inflating: pmb-1.0.0/data/p75/d2819/en.met
#  extracting: pmb-1.0.0/data/p75/d2819/en.raw
#   inflating: pmb-1.0.0/data/p75/d2819/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2819/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2819/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2819/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2819/en.drs.box
#    creating: pmb-1.0.0/data/p75/d1792/
#   inflating: pmb-1.0.0/data/p75/d1792/en.met
#  extracting: pmb-1.0.0/data/p75/d1792/en.raw
#   inflating: pmb-1.0.0/data/p75/d1792/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1792/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d1792/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d1792/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1792/en.drs.box
#    creating: pmb-1.0.0/data/p75/d1998/
#   inflating: pmb-1.0.0/data/p75/d1998/en.met
#  extracting: pmb-1.0.0/data/p75/d1998/en.raw
#   inflating: pmb-1.0.0/data/p75/d1998/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1998/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d1998/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d1998/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1998/en.drs.box
#    creating: pmb-1.0.0/data/p75/d2197/
#   inflating: pmb-1.0.0/data/p75/d2197/en.met
#  extracting: pmb-1.0.0/data/p75/d2197/en.raw
#   inflating: pmb-1.0.0/data/p75/d2197/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2197/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2197/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2197/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2197/en.drs.box
#    creating: pmb-1.0.0/data/p75/d2499/
#   inflating: pmb-1.0.0/data/p75/d2499/en.met
#   inflating: pmb-1.0.0/data/p75/d2499/it.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2499/it.tok.off
#  extracting: pmb-1.0.0/data/p75/d2499/en.raw
#   inflating: pmb-1.0.0/data/p75/d2499/it.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2499/it.drs.box
#   inflating: pmb-1.0.0/data/p75/d2499/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2499/it.tok.iob
#  extracting: pmb-1.0.0/data/p75/d2499/it.raw
#   inflating: pmb-1.0.0/data/p75/d2499/it.met
#   inflating: pmb-1.0.0/data/p75/d2499/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2499/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2499/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2499/en.drs.box
#    creating: pmb-1.0.0/data/p75/d3447/
#   inflating: pmb-1.0.0/data/p75/d3447/en.met
#  extracting: pmb-1.0.0/data/p75/d3447/en.raw
#   inflating: pmb-1.0.0/data/p75/d3447/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d3447/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d3447/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d3447/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d3447/en.drs.box
#    creating: pmb-1.0.0/data/p75/d3361/
#   inflating: pmb-1.0.0/data/p75/d3361/en.met
#  extracting: pmb-1.0.0/data/p75/d3361/en.raw
#   inflating: pmb-1.0.0/data/p75/d3361/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d3361/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d3361/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d3361/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d3361/en.drs.box
#    creating: pmb-1.0.0/data/p75/d3488/
#   inflating: pmb-1.0.0/data/p75/d3488/en.met
#   inflating: pmb-1.0.0/data/p75/d3488/de.drs.xml
#  extracting: pmb-1.0.0/data/p75/d3488/en.raw
#   inflating: pmb-1.0.0/data/p75/d3488/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d3488/de.tok.off
#   inflating: pmb-1.0.0/data/p75/d3488/de.met
#   inflating: pmb-1.0.0/data/p75/d3488/de.tok.iob
#   inflating: pmb-1.0.0/data/p75/d3488/de.drs.box
#  extracting: pmb-1.0.0/data/p75/d3488/de.raw
#   inflating: pmb-1.0.0/data/p75/d3488/de.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d3488/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d3488/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d3488/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d3488/en.drs.box
#    creating: pmb-1.0.0/data/p75/d2476/
#   inflating: pmb-1.0.0/data/p75/d2476/en.met
#   inflating: pmb-1.0.0/data/p75/d2476/de.drs.xml
#  extracting: pmb-1.0.0/data/p75/d2476/en.raw
#   inflating: pmb-1.0.0/data/p75/d2476/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2476/de.tok.off
#   inflating: pmb-1.0.0/data/p75/d2476/de.met
#   inflating: pmb-1.0.0/data/p75/d2476/de.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2476/de.drs.box
#  extracting: pmb-1.0.0/data/p75/d2476/de.raw
#   inflating: pmb-1.0.0/data/p75/d2476/de.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2476/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2476/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2476/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2476/en.drs.box
#    creating: pmb-1.0.0/data/p75/d2320/
#   inflating: pmb-1.0.0/data/p75/d2320/en.met
#  extracting: pmb-1.0.0/data/p75/d2320/en.raw
#   inflating: pmb-1.0.0/data/p75/d2320/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2320/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2320/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2320/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2320/en.drs.box
#    creating: pmb-1.0.0/data/p75/d1625/
#   inflating: pmb-1.0.0/data/p75/d1625/en.met
#  extracting: pmb-1.0.0/data/p75/d1625/en.raw
#   inflating: pmb-1.0.0/data/p75/d1625/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1625/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d1625/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d1625/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1625/en.drs.box
#    creating: pmb-1.0.0/data/p75/d1892/
#   inflating: pmb-1.0.0/data/p75/d1892/en.met
#   inflating: pmb-1.0.0/data/p75/d1892/de.drs.xml
#  extracting: pmb-1.0.0/data/p75/d1892/en.raw
#   inflating: pmb-1.0.0/data/p75/d1892/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1892/de.tok.off
#   inflating: pmb-1.0.0/data/p75/d1892/de.met
#   inflating: pmb-1.0.0/data/p75/d1892/de.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1892/de.drs.box
#  extracting: pmb-1.0.0/data/p75/d1892/de.raw
#   inflating: pmb-1.0.0/data/p75/d1892/de.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1892/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d1892/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d1892/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1892/en.drs.box
#    creating: pmb-1.0.0/data/p75/d2660/
#   inflating: pmb-1.0.0/data/p75/d2660/en.met
#   inflating: pmb-1.0.0/data/p75/d2660/en.raw
#   inflating: pmb-1.0.0/data/p75/d2660/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2660/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2660/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2660/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2660/en.drs.box
#    creating: pmb-1.0.0/data/p75/d0921/
#   inflating: pmb-1.0.0/data/p75/d0921/en.met
#   inflating: pmb-1.0.0/data/p75/d0921/nl.drs.xml
#  extracting: pmb-1.0.0/data/p75/d0921/en.raw
#   inflating: pmb-1.0.0/data/p75/d0921/nl.drs.box
#   inflating: pmb-1.0.0/data/p75/d0921/en.drs.tpl
#  extracting: pmb-1.0.0/data/p75/d0921/nl.raw
#   inflating: pmb-1.0.0/data/p75/d0921/nl.tok.iob
#   inflating: pmb-1.0.0/data/p75/d0921/nl.tok.off
#   inflating: pmb-1.0.0/data/p75/d0921/nl.met
#   inflating: pmb-1.0.0/data/p75/d0921/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d0921/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d0921/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d0921/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d0921/en.drs.box
#    creating: pmb-1.0.0/data/p75/d2971/
#   inflating: pmb-1.0.0/data/p75/d2971/en.met
#  extracting: pmb-1.0.0/data/p75/d2971/en.raw
#   inflating: pmb-1.0.0/data/p75/d2971/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2971/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2971/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2971/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2971/en.drs.box
#    creating: pmb-1.0.0/data/p75/d1837/
#   inflating: pmb-1.0.0/data/p75/d1837/en.met
#   inflating: pmb-1.0.0/data/p75/d1837/de.drs.xml
#  extracting: pmb-1.0.0/data/p75/d1837/en.raw
#   inflating: pmb-1.0.0/data/p75/d1837/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1837/de.tok.off
#   inflating: pmb-1.0.0/data/p75/d1837/de.met
#   inflating: pmb-1.0.0/data/p75/d1837/de.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1837/de.drs.box
#  extracting: pmb-1.0.0/data/p75/d1837/de.raw
#   inflating: pmb-1.0.0/data/p75/d1837/de.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1837/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d1837/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d1837/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1837/en.drs.box
#    creating: pmb-1.0.0/data/p75/d3325/
#   inflating: pmb-1.0.0/data/p75/d3325/en.met
#  extracting: pmb-1.0.0/data/p75/d3325/en.raw
#   inflating: pmb-1.0.0/data/p75/d3325/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d3325/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d3325/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d3325/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d3325/en.drs.box
#    creating: pmb-1.0.0/data/p75/d1623/
#   inflating: pmb-1.0.0/data/p75/d1623/en.met
#   inflating: pmb-1.0.0/data/p75/d1623/it.drs.xml
#   inflating: pmb-1.0.0/data/p75/d1623/it.tok.off
#  extracting: pmb-1.0.0/data/p75/d1623/en.raw
#   inflating: pmb-1.0.0/data/p75/d1623/it.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1623/it.drs.box
#   inflating: pmb-1.0.0/data/p75/d1623/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d1623/it.tok.iob
#  extracting: pmb-1.0.0/data/p75/d1623/it.raw
#   inflating: pmb-1.0.0/data/p75/d1623/it.met
#   inflating: pmb-1.0.0/data/p75/d1623/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d1623/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d1623/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d1623/en.drs.box
#    creating: pmb-1.0.0/data/p75/d2571/
#   inflating: pmb-1.0.0/data/p75/d2571/en.met
#   inflating: pmb-1.0.0/data/p75/d2571/de.drs.xml
#  extracting: pmb-1.0.0/data/p75/d2571/en.raw
#   inflating: pmb-1.0.0/data/p75/d2571/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2571/de.tok.off
#   inflating: pmb-1.0.0/data/p75/d2571/de.met
#   inflating: pmb-1.0.0/data/p75/d2571/de.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2571/de.drs.box
#  extracting: pmb-1.0.0/data/p75/d2571/de.raw
#   inflating: pmb-1.0.0/data/p75/d2571/de.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d2571/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d2571/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d2571/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d2571/en.drs.box
#    creating: pmb-1.0.0/data/p75/d3043/
#   inflating: pmb-1.0.0/data/p75/d3043/en.met
#   inflating: pmb-1.0.0/data/p75/d3043/en.raw
#   inflating: pmb-1.0.0/data/p75/d3043/en.drs.tpl
#   inflating: pmb-1.0.0/data/p75/d3043/en.drs.xml
#   inflating: pmb-1.0.0/data/p75/d3043/en.tok.off
#   inflating: pmb-1.0.0/data/p75/d3043/en.tok.iob
#   inflating: pmb-1.0.0/data/p75/d3043/en.drs.box
#    creating: pmb-1.0.0/data/p72/
#    creating: pmb-1.0.0/data/p72/d2908/
#   inflating: pmb-1.0.0/data/p72/d2908/en.met
#   inflating: pmb-1.0.0/data/p72/d2908/de.drs.xml
#  extracting: pmb-1.0.0/data/p72/d2908/en.raw
#   inflating: pmb-1.0.0/data/p72/d2908/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2908/de.tok.off
#   inflating: pmb-1.0.0/data/p72/d2908/de.met
#   inflating: pmb-1.0.0/data/p72/d2908/de.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2908/de.drs.box
#   inflating: pmb-1.0.0/data/p72/d2908/de.raw
#   inflating: pmb-1.0.0/data/p72/d2908/de.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2908/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2908/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2908/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2908/en.drs.box
#    creating: pmb-1.0.0/data/p72/d3010/
#   inflating: pmb-1.0.0/data/p72/d3010/en.met
#  extracting: pmb-1.0.0/data/p72/d3010/en.raw
#   inflating: pmb-1.0.0/data/p72/d3010/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d3010/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d3010/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d3010/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d3010/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2210/
#   inflating: pmb-1.0.0/data/p72/d2210/en.met
#  extracting: pmb-1.0.0/data/p72/d2210/en.raw
#   inflating: pmb-1.0.0/data/p72/d2210/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2210/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2210/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2210/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2210/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2634/
#   inflating: pmb-1.0.0/data/p72/d2634/en.met
#   inflating: pmb-1.0.0/data/p72/d2634/nl.drs.xml
#  extracting: pmb-1.0.0/data/p72/d2634/en.raw
#   inflating: pmb-1.0.0/data/p72/d2634/nl.drs.box
#   inflating: pmb-1.0.0/data/p72/d2634/en.drs.tpl
#  extracting: pmb-1.0.0/data/p72/d2634/nl.raw
#   inflating: pmb-1.0.0/data/p72/d2634/nl.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2634/nl.tok.off
#   inflating: pmb-1.0.0/data/p72/d2634/nl.met
#   inflating: pmb-1.0.0/data/p72/d2634/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2634/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2634/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2634/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2634/en.drs.box
#    creating: pmb-1.0.0/data/p72/d1449/
#   inflating: pmb-1.0.0/data/p72/d1449/en.met
#  extracting: pmb-1.0.0/data/p72/d1449/en.raw
#   inflating: pmb-1.0.0/data/p72/d1449/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d1449/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d1449/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d1449/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d1449/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2920/
#   inflating: pmb-1.0.0/data/p72/d2920/en.met
#  extracting: pmb-1.0.0/data/p72/d2920/en.raw
#   inflating: pmb-1.0.0/data/p72/d2920/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2920/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2920/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2920/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2920/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2957/
#   inflating: pmb-1.0.0/data/p72/d2957/en.met
#  extracting: pmb-1.0.0/data/p72/d2957/en.raw
#   inflating: pmb-1.0.0/data/p72/d2957/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2957/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2957/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2957/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2957/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2160/
#   inflating: pmb-1.0.0/data/p72/d2160/en.met
#  extracting: pmb-1.0.0/data/p72/d2160/en.raw
#   inflating: pmb-1.0.0/data/p72/d2160/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2160/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2160/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2160/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2160/en.drs.box
#    creating: pmb-1.0.0/data/p72/d1812/
#   inflating: pmb-1.0.0/data/p72/d1812/en.met
#  extracting: pmb-1.0.0/data/p72/d1812/en.raw
#   inflating: pmb-1.0.0/data/p72/d1812/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d1812/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d1812/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d1812/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d1812/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2995/
#   inflating: pmb-1.0.0/data/p72/d2995/en.met
#   inflating: pmb-1.0.0/data/p72/d2995/it.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2995/it.tok.off
#  extracting: pmb-1.0.0/data/p72/d2995/en.raw
#   inflating: pmb-1.0.0/data/p72/d2995/it.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2995/it.drs.box
#   inflating: pmb-1.0.0/data/p72/d2995/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2995/it.tok.iob
#  extracting: pmb-1.0.0/data/p72/d2995/it.raw
#   inflating: pmb-1.0.0/data/p72/d2995/it.met
#   inflating: pmb-1.0.0/data/p72/d2995/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2995/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2995/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2995/en.drs.box
#    creating: pmb-1.0.0/data/p72/d3327/
#   inflating: pmb-1.0.0/data/p72/d3327/en.met
#  extracting: pmb-1.0.0/data/p72/d3327/en.raw
#   inflating: pmb-1.0.0/data/p72/d3327/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d3327/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d3327/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d3327/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d3327/en.drs.box
#    creating: pmb-1.0.0/data/p72/d3208/
#   inflating: pmb-1.0.0/data/p72/d3208/en.met
#  extracting: pmb-1.0.0/data/p72/d3208/en.raw
#   inflating: pmb-1.0.0/data/p72/d3208/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d3208/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d3208/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d3208/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d3208/en.drs.box
#    creating: pmb-1.0.0/data/p72/d1868/
#   inflating: pmb-1.0.0/data/p72/d1868/en.met
#   inflating: pmb-1.0.0/data/p72/d1868/it.drs.xml
#   inflating: pmb-1.0.0/data/p72/d1868/it.tok.off
#  extracting: pmb-1.0.0/data/p72/d1868/en.raw
#   inflating: pmb-1.0.0/data/p72/d1868/it.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d1868/it.drs.box
#   inflating: pmb-1.0.0/data/p72/d1868/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d1868/it.tok.iob
#  extracting: pmb-1.0.0/data/p72/d1868/it.raw
#   inflating: pmb-1.0.0/data/p72/d1868/it.met
#   inflating: pmb-1.0.0/data/p72/d1868/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d1868/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d1868/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d1868/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2204/
#   inflating: pmb-1.0.0/data/p72/d2204/en.met
#  extracting: pmb-1.0.0/data/p72/d2204/en.raw
#   inflating: pmb-1.0.0/data/p72/d2204/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2204/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2204/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2204/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2204/en.drs.box
#    creating: pmb-1.0.0/data/p72/d2962/
#   inflating: pmb-1.0.0/data/p72/d2962/en.met
#   inflating: pmb-1.0.0/data/p72/d2962/de.drs.xml
#  extracting: pmb-1.0.0/data/p72/d2962/en.raw
#   inflating: pmb-1.0.0/data/p72/d2962/en.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2962/de.tok.off
#   inflating: pmb-1.0.0/data/p72/d2962/de.met
#   inflating: pmb-1.0.0/data/p72/d2962/de.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2962/de.drs.box
#  extracting: pmb-1.0.0/data/p72/d2962/de.raw
#   inflating: pmb-1.0.0/data/p72/d2962/de.drs.tpl
#   inflating: pmb-1.0.0/data/p72/d2962/en.drs.xml
#   inflating: pmb-1.0.0/data/p72/d2962/en.tok.off
#   inflating: pmb-1.0.0/data/p72/d2962/en.tok.iob
#   inflating: pmb-1.0.0/data/p72/d2962/en.drs.box
#    creating: pmb-1.0.0/data/p32/
#    creating: pmb-1.0.0/data/p32/d2799/
#   inflating: pmb-1.0.0/data/p32/d2799/en.met
#   inflating: pmb-1.0.0/data/p32/d2799/de.drs.xml
#  extracting: pmb-1.0.0/data/p32/d2799/en.raw
#   inflating: pmb-1.0.0/data/p32/d2799/en.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d2799/de.tok.off
#   inflating: pmb-1.0.0/data/p32/d2799/de.met
#   inflating: pmb-1.0.0/data/p32/d2799/de.tok.iob
#   inflating: pmb-1.0.0/data/p32/d2799/de.drs.box
#  extracting: pmb-1.0.0/data/p32/d2799/de.raw
#   inflating: pmb-1.0.0/data/p32/d2799/de.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d2799/en.drs.xml
#   inflating: pmb-1.0.0/data/p32/d2799/en.tok.off
#   inflating: pmb-1.0.0/data/p32/d2799/en.tok.iob
#   inflating: pmb-1.0.0/data/p32/d2799/en.drs.box
#    creating: pmb-1.0.0/data/p32/d3348/
#   inflating: pmb-1.0.0/data/p32/d3348/en.met
#  extracting: pmb-1.0.0/data/p32/d3348/en.raw
#   inflating: pmb-1.0.0/data/p32/d3348/en.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d3348/en.drs.xml
#   inflating: pmb-1.0.0/data/p32/d3348/en.tok.off
#   inflating: pmb-1.0.0/data/p32/d3348/en.tok.iob
#   inflating: pmb-1.0.0/data/p32/d3348/en.drs.box
#    creating: pmb-1.0.0/data/p32/d3096/
#   inflating: pmb-1.0.0/data/p32/d3096/en.met
#  extracting: pmb-1.0.0/data/p32/d3096/en.raw
#   inflating: pmb-1.0.0/data/p32/d3096/en.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d3096/en.drs.xml
#   inflating: pmb-1.0.0/data/p32/d3096/en.tok.off
#   inflating: pmb-1.0.0/data/p32/d3096/en.tok.iob
#   inflating: pmb-1.0.0/data/p32/d3096/en.drs.box
#    creating: pmb-1.0.0/data/p32/d0835/
#   inflating: pmb-1.0.0/data/p32/d0835/en.met
#   inflating: pmb-1.0.0/data/p32/d0835/nl.drs.xml
#   inflating: pmb-1.0.0/data/p32/d0835/de.drs.xml
#  extracting: pmb-1.0.0/data/p32/d0835/en.raw
#   inflating: pmb-1.0.0/data/p32/d0835/nl.drs.box
#   inflating: pmb-1.0.0/data/p32/d0835/en.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d0835/de.tok.off
#  extracting: pmb-1.0.0/data/p32/d0835/nl.raw
#   inflating: pmb-1.0.0/data/p32/d0835/nl.tok.iob
#   inflating: pmb-1.0.0/data/p32/d0835/nl.tok.off
#   inflating: pmb-1.0.0/data/p32/d0835/de.met
#   inflating: pmb-1.0.0/data/p32/d0835/nl.met
#   inflating: pmb-1.0.0/data/p32/d0835/de.tok.iob
#   inflating: pmb-1.0.0/data/p32/d0835/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d0835/de.drs.box
#  extracting: pmb-1.0.0/data/p32/d0835/de.raw
#   inflating: pmb-1.0.0/data/p32/d0835/de.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d0835/en.drs.xml
#   inflating: pmb-1.0.0/data/p32/d0835/en.tok.off
#   inflating: pmb-1.0.0/data/p32/d0835/en.tok.iob
#   inflating: pmb-1.0.0/data/p32/d0835/en.drs.box
#    creating: pmb-1.0.0/data/p32/d2835/
#   inflating: pmb-1.0.0/data/p32/d2835/en.met
#   inflating: pmb-1.0.0/data/p32/d2835/it.drs.xml
#   inflating: pmb-1.0.0/data/p32/d2835/it.tok.off
#  extracting: pmb-1.0.0/data/p32/d2835/en.raw
#   inflating: pmb-1.0.0/data/p32/d2835/it.drs.tpl
#   inflating: pmb-1.0.0/data/p32/d2835/it.drs.box
#   inflating: pmb-1.0.0/data/p32/d2835/en.drs.tpl
# ...
#   inflating: pmb-1.0.0/data/p85/d0825/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0825/en.drs.box
#    creating: pmb-1.0.0/data/p85/d3375/
#   inflating: pmb-1.0.0/data/p85/d3375/en.met
#   inflating: pmb-1.0.0/data/p85/d3375/nl.drs.xml
#  extracting: pmb-1.0.0/data/p85/d3375/en.raw
#   inflating: pmb-1.0.0/data/p85/d3375/nl.drs.box
#   inflating: pmb-1.0.0/data/p85/d3375/en.drs.tpl
#  extracting: pmb-1.0.0/data/p85/d3375/nl.raw
#   inflating: pmb-1.0.0/data/p85/d3375/nl.tok.iob
#   inflating: pmb-1.0.0/data/p85/d3375/nl.tok.off
#   inflating: pmb-1.0.0/data/p85/d3375/nl.met
#   inflating: pmb-1.0.0/data/p85/d3375/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d3375/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d3375/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d3375/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d3375/en.drs.box
#    creating: pmb-1.0.0/data/p85/d3191/
#   inflating: pmb-1.0.0/data/p85/d3191/en.met
#  extracting: pmb-1.0.0/data/p85/d3191/en.raw
#   inflating: pmb-1.0.0/data/p85/d3191/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d3191/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d3191/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d3191/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d3191/en.drs.box
#    creating: pmb-1.0.0/data/p85/d1456/
#   inflating: pmb-1.0.0/data/p85/d1456/en.met
#   inflating: pmb-1.0.0/data/p85/d1456/it.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1456/de.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1456/it.tok.off
#  extracting: pmb-1.0.0/data/p85/d1456/en.raw
#   inflating: pmb-1.0.0/data/p85/d1456/it.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1456/it.drs.box
#   inflating: pmb-1.0.0/data/p85/d1456/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1456/it.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1456/de.tok.off
#  extracting: pmb-1.0.0/data/p85/d1456/it.raw
#   inflating: pmb-1.0.0/data/p85/d1456/de.met
#   inflating: pmb-1.0.0/data/p85/d1456/de.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1456/de.drs.box
#  extracting: pmb-1.0.0/data/p85/d1456/de.raw
#   inflating: pmb-1.0.0/data/p85/d1456/de.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1456/it.met
#   inflating: pmb-1.0.0/data/p85/d1456/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1456/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d1456/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1456/en.drs.box
#    creating: pmb-1.0.0/data/p85/d1670/
#   inflating: pmb-1.0.0/data/p85/d1670/en.met
#   inflating: pmb-1.0.0/data/p85/d1670/it.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1670/it.tok.off
#  extracting: pmb-1.0.0/data/p85/d1670/en.raw
#   inflating: pmb-1.0.0/data/p85/d1670/it.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1670/it.drs.box
#   inflating: pmb-1.0.0/data/p85/d1670/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1670/it.tok.iob
#  extracting: pmb-1.0.0/data/p85/d1670/it.raw
#   inflating: pmb-1.0.0/data/p85/d1670/it.met
#   inflating: pmb-1.0.0/data/p85/d1670/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1670/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d1670/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1670/en.drs.box
#    creating: pmb-1.0.0/data/p85/d3201/
#   inflating: pmb-1.0.0/data/p85/d3201/en.met
#  extracting: pmb-1.0.0/data/p85/d3201/en.raw
#   inflating: pmb-1.0.0/data/p85/d3201/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d3201/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d3201/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d3201/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d3201/en.drs.box
#    creating: pmb-1.0.0/data/p85/d0963/
#   inflating: pmb-1.0.0/data/p85/d0963/en.met
#  extracting: pmb-1.0.0/data/p85/d0963/en.raw
#   inflating: pmb-1.0.0/data/p85/d0963/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0963/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0963/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d0963/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0963/en.drs.box
#    creating: pmb-1.0.0/data/p85/d0915/
#   inflating: pmb-1.0.0/data/p85/d0915/en.met
#   inflating: pmb-1.0.0/data/p85/d0915/nl.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0915/de.drs.xml
#  extracting: pmb-1.0.0/data/p85/d0915/en.raw
#   inflating: pmb-1.0.0/data/p85/d0915/nl.drs.box
#   inflating: pmb-1.0.0/data/p85/d0915/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0915/de.tok.off
#  extracting: pmb-1.0.0/data/p85/d0915/nl.raw
#   inflating: pmb-1.0.0/data/p85/d0915/nl.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0915/nl.tok.off
#   inflating: pmb-1.0.0/data/p85/d0915/de.met
#   inflating: pmb-1.0.0/data/p85/d0915/nl.met
#   inflating: pmb-1.0.0/data/p85/d0915/de.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0915/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0915/de.drs.box
#  extracting: pmb-1.0.0/data/p85/d0915/de.raw
#   inflating: pmb-1.0.0/data/p85/d0915/de.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0915/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0915/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d0915/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0915/en.drs.box
#    creating: pmb-1.0.0/data/p85/d1540/
#   inflating: pmb-1.0.0/data/p85/d1540/en.met
#  extracting: pmb-1.0.0/data/p85/d1540/en.raw
#   inflating: pmb-1.0.0/data/p85/d1540/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1540/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1540/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d1540/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1540/en.drs.box
#    creating: pmb-1.0.0/data/p85/d0936/
#   inflating: pmb-1.0.0/data/p85/d0936/en.met
#   inflating: pmb-1.0.0/data/p85/d0936/nl.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0936/de.drs.xml
#  extracting: pmb-1.0.0/data/p85/d0936/en.raw
#   inflating: pmb-1.0.0/data/p85/d0936/nl.drs.box
#   inflating: pmb-1.0.0/data/p85/d0936/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0936/de.tok.off
#  extracting: pmb-1.0.0/data/p85/d0936/nl.raw
#   inflating: pmb-1.0.0/data/p85/d0936/nl.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0936/nl.tok.off
#   inflating: pmb-1.0.0/data/p85/d0936/de.met
#   inflating: pmb-1.0.0/data/p85/d0936/nl.met
#   inflating: pmb-1.0.0/data/p85/d0936/de.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0936/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0936/de.drs.box
#  extracting: pmb-1.0.0/data/p85/d0936/de.raw
#   inflating: pmb-1.0.0/data/p85/d0936/de.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0936/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0936/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d0936/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0936/en.drs.box
#    creating: pmb-1.0.0/data/p85/d2911/
#   inflating: pmb-1.0.0/data/p85/d2911/en.met
#   inflating: pmb-1.0.0/data/p85/d2911/it.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2911/de.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2911/it.tok.off
#  extracting: pmb-1.0.0/data/p85/d2911/en.raw
#   inflating: pmb-1.0.0/data/p85/d2911/it.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2911/it.drs.box
#   inflating: pmb-1.0.0/data/p85/d2911/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2911/it.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2911/de.tok.off
#  extracting: pmb-1.0.0/data/p85/d2911/it.raw
#   inflating: pmb-1.0.0/data/p85/d2911/de.met
#   inflating: pmb-1.0.0/data/p85/d2911/de.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2911/de.drs.box
#  extracting: pmb-1.0.0/data/p85/d2911/de.raw
#   inflating: pmb-1.0.0/data/p85/d2911/de.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2911/it.met
#   inflating: pmb-1.0.0/data/p85/d2911/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2911/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d2911/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2911/en.drs.box
#    creating: pmb-1.0.0/data/p85/d0903/
#   inflating: pmb-1.0.0/data/p85/d0903/en.met
#  extracting: pmb-1.0.0/data/p85/d0903/en.raw
#   inflating: pmb-1.0.0/data/p85/d0903/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0903/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0903/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d0903/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0903/en.drs.box
#    creating: pmb-1.0.0/data/p85/d2626/
#   inflating: pmb-1.0.0/data/p85/d2626/en.met
#   inflating: pmb-1.0.0/data/p85/d2626/de.drs.xml
#  extracting: pmb-1.0.0/data/p85/d2626/en.raw
#   inflating: pmb-1.0.0/data/p85/d2626/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2626/de.tok.off
#   inflating: pmb-1.0.0/data/p85/d2626/de.met
#   inflating: pmb-1.0.0/data/p85/d2626/de.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2626/de.drs.box
#  extracting: pmb-1.0.0/data/p85/d2626/de.raw
#   inflating: pmb-1.0.0/data/p85/d2626/de.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2626/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2626/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d2626/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2626/en.drs.box
#    creating: pmb-1.0.0/data/p85/d1577/
#   inflating: pmb-1.0.0/data/p85/d1577/en.met
#   inflating: pmb-1.0.0/data/p85/d1577/nl.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1577/it.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1577/it.tok.off
#  extracting: pmb-1.0.0/data/p85/d1577/en.raw
#   inflating: pmb-1.0.0/data/p85/d1577/it.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1577/nl.drs.box
#   inflating: pmb-1.0.0/data/p85/d1577/it.drs.box
#   inflating: pmb-1.0.0/data/p85/d1577/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1577/it.tok.iob
#  extracting: pmb-1.0.0/data/p85/d1577/nl.raw
#   inflating: pmb-1.0.0/data/p85/d1577/nl.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1577/nl.tok.off
#  extracting: pmb-1.0.0/data/p85/d1577/it.raw
#   inflating: pmb-1.0.0/data/p85/d1577/nl.met
#   inflating: pmb-1.0.0/data/p85/d1577/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1577/it.met
#   inflating: pmb-1.0.0/data/p85/d1577/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1577/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d1577/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1577/en.drs.box
#    creating: pmb-1.0.0/data/p85/d1488/
#   inflating: pmb-1.0.0/data/p85/d1488/en.met
#  extracting: pmb-1.0.0/data/p85/d1488/en.raw
#   inflating: pmb-1.0.0/data/p85/d1488/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1488/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1488/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d1488/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1488/en.drs.box
#    creating: pmb-1.0.0/data/p85/d2020/
#   inflating: pmb-1.0.0/data/p85/d2020/en.met
#  extracting: pmb-1.0.0/data/p85/d2020/en.raw
#   inflating: pmb-1.0.0/data/p85/d2020/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2020/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2020/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d2020/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2020/en.drs.box
#    creating: pmb-1.0.0/data/p85/d2721/
#   inflating: pmb-1.0.0/data/p85/d2721/en.met
#  extracting: pmb-1.0.0/data/p85/d2721/en.raw
#   inflating: pmb-1.0.0/data/p85/d2721/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2721/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2721/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d2721/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2721/en.drs.box
#    creating: pmb-1.0.0/data/p85/d0889/
#   inflating: pmb-1.0.0/data/p85/d0889/en.met
#   inflating: pmb-1.0.0/data/p85/d0889/nl.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0889/it.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0889/de.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0889/it.tok.off
#  extracting: pmb-1.0.0/data/p85/d0889/en.raw
#   inflating: pmb-1.0.0/data/p85/d0889/it.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0889/nl.drs.box
#   inflating: pmb-1.0.0/data/p85/d0889/it.drs.box
#   inflating: pmb-1.0.0/data/p85/d0889/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0889/it.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0889/de.tok.off
#  extracting: pmb-1.0.0/data/p85/d0889/nl.raw
#   inflating: pmb-1.0.0/data/p85/d0889/nl.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0889/nl.tok.off
#  extracting: pmb-1.0.0/data/p85/d0889/it.raw
#   inflating: pmb-1.0.0/data/p85/d0889/de.met
#   inflating: pmb-1.0.0/data/p85/d0889/nl.met
#   inflating: pmb-1.0.0/data/p85/d0889/de.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0889/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0889/de.drs.box
#  extracting: pmb-1.0.0/data/p85/d0889/de.raw
#   inflating: pmb-1.0.0/data/p85/d0889/de.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0889/it.met
#   inflating: pmb-1.0.0/data/p85/d0889/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0889/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d0889/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0889/en.drs.box
#    creating: pmb-1.0.0/data/p85/d0940/
#   inflating: pmb-1.0.0/data/p85/d0940/en.met
#   inflating: pmb-1.0.0/data/p85/d0940/nl.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0940/it.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0940/de.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0940/it.tok.off
#  extracting: pmb-1.0.0/data/p85/d0940/en.raw
#   inflating: pmb-1.0.0/data/p85/d0940/it.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0940/nl.drs.box
#   inflating: pmb-1.0.0/data/p85/d0940/it.drs.box
#   inflating: pmb-1.0.0/data/p85/d0940/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0940/it.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0940/de.tok.off
#  extracting: pmb-1.0.0/data/p85/d0940/nl.raw
#   inflating: pmb-1.0.0/data/p85/d0940/nl.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0940/nl.tok.off
#  extracting: pmb-1.0.0/data/p85/d0940/it.raw
#   inflating: pmb-1.0.0/data/p85/d0940/de.met
#   inflating: pmb-1.0.0/data/p85/d0940/nl.met
#   inflating: pmb-1.0.0/data/p85/d0940/de.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0940/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0940/de.drs.box
#  extracting: pmb-1.0.0/data/p85/d0940/de.raw
#   inflating: pmb-1.0.0/data/p85/d0940/de.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0940/it.met
#   inflating: pmb-1.0.0/data/p85/d0940/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0940/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d0940/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0940/en.drs.box
#    creating: pmb-1.0.0/data/p85/d0942/
#   inflating: pmb-1.0.0/data/p85/d0942/en.met
#   inflating: pmb-1.0.0/data/p85/d0942/nl.drs.xml
#  extracting: pmb-1.0.0/data/p85/d0942/en.raw
#   inflating: pmb-1.0.0/data/p85/d0942/nl.drs.box
#   inflating: pmb-1.0.0/data/p85/d0942/en.drs.tpl
#  extracting: pmb-1.0.0/data/p85/d0942/nl.raw
#   inflating: pmb-1.0.0/data/p85/d0942/nl.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0942/nl.tok.off
#   inflating: pmb-1.0.0/data/p85/d0942/nl.met
#   inflating: pmb-1.0.0/data/p85/d0942/nl.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d0942/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d0942/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d0942/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d0942/en.drs.box
#    creating: pmb-1.0.0/data/p85/d2483/
#   inflating: pmb-1.0.0/data/p85/d2483/en.met
#  extracting: pmb-1.0.0/data/p85/d2483/en.raw
#   inflating: pmb-1.0.0/data/p85/d2483/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2483/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2483/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d2483/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2483/en.drs.box
#    creating: pmb-1.0.0/data/p85/d1474/
#   inflating: pmb-1.0.0/data/p85/d1474/en.met
#   inflating: pmb-1.0.0/data/p85/d1474/en.raw
#   inflating: pmb-1.0.0/data/p85/d1474/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d1474/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d1474/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d1474/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d1474/en.drs.box
#    creating: pmb-1.0.0/data/p85/d2097/
#   inflating: pmb-1.0.0/data/p85/d2097/en.met
#  extracting: pmb-1.0.0/data/p85/d2097/en.raw
#   inflating: pmb-1.0.0/data/p85/d2097/en.drs.tpl
#   inflating: pmb-1.0.0/data/p85/d2097/en.drs.xml
#   inflating: pmb-1.0.0/data/p85/d2097/en.tok.off
#   inflating: pmb-1.0.0/data/p85/d2097/en.tok.iob
#   inflating: pmb-1.0.0/data/p85/d2097/en.drs.box
#    creating: pmb-1.0.0/licenses/
#   inflating: pmb-1.0.0/licenses/PMB_LICENSE.txt
#   inflating: pmb-1.0.0/licenses/ODC-BY.txt
#   inflating: pmb-1.0.0/licenses/RTE3-ITA-README.txt
#   inflating: pmb-1.0.0/licenses/Tatoeba_LICENSE.txt
#   inflating: pmb-1.0.0/licenses/RTE3-DE-README.txt
#   inflating: pmb-1.0.0/licenses/RTE3-NL-README.txt

# %% [markdown]
# A word-document matrix (A) is just the transpose of the result of Sklearn's count vectorization.

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()
corpus_vectorized = cv.fit_transform(corpus)
A = corpus_vectorized.T

# %% [markdown]
# We also saves the vocabulary computed by the CountVectorizer object as a list. We will use it later to retrieve the vector representation of the words.

# %%
vocabulary = list(cv.get_feature_names_out())

# %% [markdown]
# Let's define a utility function to compute the cosine similarity of two vectors given two words and a vector space model.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def similarity(model, word1, word2):
    vector1 = model[vocabulary.index(word1)]
    vector2 = model[vocabulary.index(word2)]
    return cosine_similarity(vector1, vector2)[0][0]

# %% [markdown]
# The word-document matrix is a very sparse vector model which suffer from the *curse of dimensionality*, as shown by the many zeros returned as similarity scores.

# %%
print (similarity(A, 'cat', 'dog'))
print (similarity(A, 'cat', 'man'))
print (similarity(A, 'cat', 'car'))
print (similarity(A, 'cat', 'plane'))
# Out:
# 0.0816496580927726
# 0.0
# 0.0
# 0.0

# %% [markdown]
# The TruncatedSVD function computes the Singular Value Decomposition, truncates the components to the top N, and returns their product, representing the best approximation of the original matrix as per the Latent Semantic Analysis algorithm.

# %%
from sklearn.decomposition import TruncatedSVD
import scipy
svd =  TruncatedSVD(n_components = 50)
A_transformed = scipy.sparse.csc_matrix(svd.fit_transform(A))

# %% [markdown]
# The LSA matrix is dense and provides more reasonable similarity scores.

# %%
print (similarity(A_transformed, 'cat', 'dog'))
print (similarity(A_transformed, 'cat', 'man'))
print (similarity(A_transformed, 'cat', 'car'))
print (similarity(A_transformed, 'cat', 'plane'))
# Out:
# 0.3726249551384404
# 0.2868626933317482
# 0.13929558292776395
# 0.01619782189079399
